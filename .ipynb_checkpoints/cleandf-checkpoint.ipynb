# %%
import pandas as pd 

df = pd.read_excel('USA_Supercharger_Stations.xlsx')
df
# Out:
#         Supercharger                    Street Address        City State  \
# 0       Soldotna, AK           43540 Whistle Hill Loop    Soldotna    AK
# 1         Auburn, AL                   1627 Opelika Rd      Auburn    AL
# 2     Birmingham, AL  2221 Richard Arrington Jr Blvd N  Birmingham    AL
# 3         Athens, AL                        1325 US-72      Athens    AL
# 4         Steele, AL             905 Steele Station Rd      Steele    AL
# ...              ...                               ...         ...   ...
# 1188  Evansville, WY                    6985 Nugget St  Evansville    WY
# 1189    Gillette, WY        Hampton Inn, 211 Decker Ct    Gillette    WY
# 1190    Cheyenne, WY              1400 Dell Range Blvd    Cheyenne    WY
# 1191     Laramie, WY                1673 Centennial Dr     Laramie    WY
# 1192     Rawlins, WY                   2370 E Cedar St     Rawlins    WY
#
#      Zipcode Country                     GPS Statues  Open Date
# ...

# %%
x = df.drop(columns=['Open Date', 'Statues'])
x
# Out:
#         Supercharger                    Street Address        City State  \
# 0       Soldotna, AK           43540 Whistle Hill Loop    Soldotna    AK
# 1         Auburn, AL                   1627 Opelika Rd      Auburn    AL
# 2     Birmingham, AL  2221 Richard Arrington Jr Blvd N  Birmingham    AL
# 3         Athens, AL                        1325 US-72      Athens    AL
# 4         Steele, AL             905 Steele Station Rd      Steele    AL
# ...              ...                               ...         ...   ...
# 1188  Evansville, WY                    6985 Nugget St  Evansville    WY
# 1189    Gillette, WY        Hampton Inn, 211 Decker Ct    Gillette    WY
# 1190    Cheyenne, WY              1400 Dell Range Blvd    Cheyenne    WY
# 1191     Laramie, WY                1673 Centennial Dr     Laramie    WY
# 1192     Rawlins, WY                   2370 E Cedar St     Rawlins    WY
#
#      Zipcode Country                     GPS
# 0      99669     USA  60.494628, -151.045047
# ...
